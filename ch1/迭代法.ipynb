# %% [markdown]
# 假设在空池塘中放入一颗水藻，该类水藻会每周长出三颗新的水藻，问十周后，池塘中有多少颗水藻？

# %%
x = 1 # 初始条件：第一周水藻数量
times = 1 # 迭代次数
while times < 10: # 迭代过程
    y = 3 * x
    x = x + y
    times += 1
    print("第%d周的水藻数量:%d" % (times, x))
# Out:
# 第2周的水藻数量:4
# 第3周的水藻数量:16
# 第4周的水藻数量:64
# 第5周的水藻数量:256
# 第6周的水藻数量:1024
# 第7周的水藻数量:4096
# 第8周的水藻数量:16384
# 第9周的水藻数量:65536
# 第10周的水藻数量:262144

# %% [markdown]
# 求解方程x^3+e^x/2+5x-6=0的根。 建立迭代关系式： x=(6-x^3-(e^x)/2)/5

# %%
import math
x = 0 # 初始条件
for i in range(100): # 控制总的迭代次数
    x = (6 - x**3 - (math.e**x)/2.0)/5.0 
    print(str(i)+":"+str(x))
# Out:
# 0:1.1
# 1:0.6333833976053566
# 2:0.9607831386993697
# 3:0.7612451427547097
# 4:0.8976785421774022
# 5:0.8099353339786866
# 6:0.8689609915826384
# 7:0.8303274798888033
# 8:0.8561001981471914
# 9:0.8391152621768908
# 10:0.850401517669936
# 11:0.8429422148469066
# 12:0.8478899896983665
# 13:0.8446158829987237
# 14:0.846785884647397
# 15:0.8453491541692075
# 16:0.8463010523357257
# 17:0.845670665332824
# 18:0.8460882605809683
# 19:0.8458116831312754
# 20:0.8459948874407963
# 21:0.8458735439749878
# 22:0.8459539192397146
# 23:0.8459006824726572
# 24:0.8459359448863271
# 25:0.8459125885326444
# 26:0.8459280589817704
# 27:0.8459178119620006
# 28:0.8459245992200859
# 29:0.8459201035986089
# 30:0.8459230813336305
# 31:0.8459211089938277
# 32:0.8459224153988485
# 33:0.8459215500849682
# 34:0.8459221232367937
# 35:0.8459217436023836
# 36:0.8459219950581153
# 37:0.8459218285031991
# 38:0.8459219388229844
# 39:0.8459218657512633
# 40:0.8459219141512543
# 41:0.8459218820929006
# ...

# %%
x = 0 # 初始条件
delta = 0.00001 # 控制退出条件
times = 0 # 用来显示迭代次数
while True: # 条件为True，如果没有别的退出手段，while循环将会无限进行下去
    x_old = x
    x = (6 - x**3 - (math.e**x)/2.0)/5.0 
    print(str(times)+":"+str(x))
    times += 1
    if abs(x - x_old) < delta:
        break # 如果符合退出条件，则直接退出循环
# Out:
# 0:1.1
# 1:0.6333833976053566
# 2:0.9607831386993697
# 3:0.7612451427547097
# 4:0.8976785421774022
# 5:0.8099353339786866
# 6:0.8689609915826384
# 7:0.8303274798888033
# 8:0.8561001981471914
# 9:0.8391152621768908
# 10:0.850401517669936
# 11:0.8429422148469066
# 12:0.8478899896983665
# 13:0.8446158829987237
# 14:0.846785884647397
# 15:0.8453491541692075
# 16:0.8463010523357257
# 17:0.845670665332824
# 18:0.8460882605809683
# 19:0.8458116831312754
# 20:0.8459948874407963
# 21:0.8458735439749878
# 22:0.8459539192397146
# 23:0.8459006824726572
# 24:0.8459359448863271
# 25:0.8459125885326444
# 26:0.8459280589817704
# 27:0.8459178119620006
# 28:0.8459245992200859

# %% [markdown]
# 爬山法求解上述方程

# %%
import random
# 搜索步长
delta = 0.001
# 通过代入0和1，可估计出解在0和1之间
BOUND = [0, 1]

def f(x):
    return x**3 + (math.e**x)/2.0 + 5.0*x - 6

def hillClimbing(x, f):
    times = 0
    print(str(times)+":"+str(x))
    while abs( f(x+delta) ) < abs(f(x)) and x+delta <= BOUND[1] and x+delta >= BOUND[0]:
        x = x + delta
        times += 1
        print(str(times)+":"+str(x))
    while abs( f(x-delta) ) < abs(f(x)) and x-delta <= BOUND[1] and x-delta >= BOUND[0]:
        x = x - delta
        times += 1
        print(str(times)+":"+str(x))
    return x

x = random.random() * ( BOUND[1]-BOUND[0] ) + BOUND[0]
x_value = hillClimbing(x, f)
# Out:
# 0:0.6026843321428254
# 1:0.6036843321428254
# 2:0.6046843321428254
# 3:0.6056843321428254
# 4:0.6066843321428254
# 5:0.6076843321428254
# 6:0.6086843321428254
# 7:0.6096843321428254
# 8:0.6106843321428254
# 9:0.6116843321428254
# 10:0.6126843321428254
# 11:0.6136843321428254
# 12:0.6146843321428254
# 13:0.6156843321428254
# 14:0.6166843321428254
# 15:0.6176843321428254
# 16:0.6186843321428254
# 17:0.6196843321428254
# 18:0.6206843321428254
# 19:0.6216843321428254
# 20:0.6226843321428254
# 21:0.6236843321428254
# 22:0.6246843321428254
# 23:0.6256843321428254
# 24:0.6266843321428254
# 25:0.6276843321428254
# 26:0.6286843321428254
# 27:0.6296843321428254
# 28:0.6306843321428254
# 29:0.6316843321428254
# 30:0.6326843321428254
# 31:0.6336843321428254
# 32:0.6346843321428254
# 33:0.6356843321428254
# 34:0.6366843321428254
# 35:0.6376843321428254
# 36:0.6386843321428254
# 37:0.6396843321428254
# 38:0.6406843321428254
# 39:0.6416843321428254
# 40:0.6426843321428254
# 41:0.6436843321428254
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 1, 100)
y = f(x)
plt.plot(x, y, color="red", linewidth=1)
plt.show()
